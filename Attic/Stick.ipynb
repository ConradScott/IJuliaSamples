# %%
using Distributions
using PyPlot

# %%
function middle()
    xs = rand(Uniform(0, 1), 2)
    abs(xs[1] - xs[2])
end
# Out:
# middle (generic function with 1 method)

# %%
n = 1000000
xs = [abs(rand(Uniform(0, 1)) - rand(Uniform(0, 1))) for i in 1:n]
nbins = 50
plt[:hist](xs, nbins)
mean(xs)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9efed4b210>)
# 0.333286143680113
